# %%
# !pip install PyPDF2

# %%
# !pip install wordcloud

# %%
# !pip install spacy

# %%
import wordcloud

# %%
# !pip install wordcloud

# %%
import docx
import glob
import doc
import textract
import antiword
from PyPDF2 import PdfFileReader
import re
import re
import nltk

# %%
import os,re
import docx2txt
import textract
import pandas as pd
import numpy as np
from docx import Document
import nltk
nltk.download('punkt')
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.naive_bayes import MultinomialNB
from sklearn.multiclass import OneVsRestClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score,precision_score
from pandas.plotting import scatter_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
nltk.download("stopwords")
import xgboost as xgb
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\q\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\q\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # List all the Resumes

# %%
all=os.listdir(r'C:\Users\q\Desktop\Resumes')

# %%
all
# Out:
# ['Internship',
#  'Peoplesoft resumes',
#  'React Developer_Deepakreddy.docx',
#  'React Developer_Haripriya.docx',
#  'React Developer_Kamalakar Reddy.docx',
#  'React Developer_Naveen sadhu.docx',
#  'React Developer_PavasGoswami.docx',
#  'React Developer_Pragnya.docx',
#  'React Developer_Sarala Madasu-converted.docx',
#  'React Developer_Thirupathiamma.docx',
#  'React Developer_Vinay Reddy.docx',
#  'React Dev_Krishna Kanth.docx',
#  'React Dev_Krishna Kanth_Musquare Technologies.docx',
#  'React JS Developer_AnjaniPriyadarshini.docx',
#  'React JS Developer_KotaniDurgaprasad[3_1] (1)-converted.docx',
#  'React JS Developer_Venkatalakshmi (1)-converted.docx',
#  'Reactjs Developer_kambala sai surendra_Musquare Technologies.docx',
#  'Reactjs Developer_M Lokesh Babu_Musquare Technologies.docx',
#  'Reactjs Developer_M Lokesh.docx',
#  'Reactjs Developer_MD Khizaruddin Rauf _Musquare Technologies.docx',
#  'Reactjs Developer_Prabakaran_Musquare Technologies.pdf',
# ...

# %%
len(all)
# Out:
# 26

# %% [markdown]
# # For SQL Developer

# %%
path=r'C:\Users\q\Desktop\Resumes\SQL Developer Lightning insight'
all_files=glob.glob(path + "/*.docx")
all_files
# Out:
# ['C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\Anil kumar.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\AradhanaTripathi[4_0].docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\Buddha Vamsi.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\kamballapradeep.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\Nazeer Basha.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\Neeraj Mishra.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\premsai.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\Priyanka L.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\PSyamKumar[2_3].docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\Rajupavanakumari[2_10].docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\Ramalakshmi K.docx',
# ...

# %%
all_files
# Out:
# ['C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\Anil kumar.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\AradhanaTripathi[4_0].docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\Buddha Vamsi.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\kamballapradeep.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\Nazeer Basha.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\Neeraj Mishra.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\premsai.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\Priyanka L.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\PSyamKumar[2_3].docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\Rajupavanakumari[2_10].docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\SQL Developer Lightning insight\\Ramalakshmi K.docx',
# ...

# %%
len(all_files)
# Out:
# 14

# %%
def readtxt(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)

# %%
li=[]
for filename in all_files:
    dummy_1=readtxt(filename)
    li.append(dummy_1)

# %%
import pandas as pd
df=pd.DataFrame()

# %%
for files in all_files:
    print(files)
    df["cv"]=li
# Out:
# C:\Users\q\Desktop\Resumes\SQL Developer Lightning insight\Anil kumar.docx
# C:\Users\q\Desktop\Resumes\SQL Developer Lightning insight\AradhanaTripathi[4_0].docx
# C:\Users\q\Desktop\Resumes\SQL Developer Lightning insight\Buddha Vamsi.docx
# C:\Users\q\Desktop\Resumes\SQL Developer Lightning insight\kamballapradeep.docx
# C:\Users\q\Desktop\Resumes\SQL Developer Lightning insight\Nazeer Basha.docx
# C:\Users\q\Desktop\Resumes\SQL Developer Lightning insight\Neeraj Mishra.docx
# C:\Users\q\Desktop\Resumes\SQL Developer Lightning insight\premsai.docx
# C:\Users\q\Desktop\Resumes\SQL Developer Lightning insight\Priyanka L.docx
# C:\Users\q\Desktop\Resumes\SQL Developer Lightning insight\PSyamKumar[2_3].docx
# C:\Users\q\Desktop\Resumes\SQL Developer Lightning insight\Rajupavanakumari[2_10].docx
# C:\Users\q\Desktop\Resumes\SQL Developer Lightning insight\Ramalakshmi K.docx
# C:\Users\q\Desktop\Resumes\SQL Developer Lightning insight\RameshNataru[3_4].docx
# ...

# %%
label_list='SQL Developer'

# %%
df["label"]=label_list

# %%
df
# Out:
#                                                    cv          label
# 0   ANIL KUMAR MADDUKURI  \t\t\nSQL & MSBI Develop...  SQL Developer
# 1   \nAradhana Tripathi\n\nCurrent Location: Gachi...  SQL Developer
# 2   BUDDHA VAMSI                                  ...  SQL Developer
# 3   KAMBALLA PRADEEP                              ...  SQL Developer
# 4   \n\n\n Hyderabad\n\nNazeer Basha\nSQL and Pow...  SQL Developer
# 5    \n                                        Res...  SQL Developer
# 6   SQL DEVELOPER\nName: -   Bandi prem sai\n\n\nW...  SQL Developer
# 7                                          SQL SER...  SQL Developer
# 8                                          SQL SER...  SQL Developer
# 9    RAJU PAVANA KUMARI\n\n\nProfessional Summary:...  SQL Developer
# 10                                      resume\n\n...  SQL Developer
# 11  Name: Ramesh\n\nCareer Objective: \n          ...  SQL Developer
# 12  Career objective\n\t\nA rewarding opportunity ...  SQL Developer
# ...

# %% [markdown]
# # For PeopleSoft

# %%
path=r'C:\Users\q\Desktop\Resumes\Peoplesoft resumes'
all_files=glob.glob(path + "/*.docx")
all_files
# Out:
# ['C:\\Users\\q\\Desktop\\Resumes\\Peoplesoft resumes\\Peoplesoft Admin_AnubhavSingh.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\Peoplesoft resumes\\Peoplesoft Admin_G Ananda Rayudu.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\Peoplesoft resumes\\Peoplesoft Admin_Gangareddy.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\Peoplesoft resumes\\Peoplesoft Admin_Murali.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\Peoplesoft resumes\\Peoplesoft Admin_Priyanka Ramadoss.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\Peoplesoft resumes\\Peoplesoft Admin_SirazuddinMohammad.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\Peoplesoft resumes\\Peoplesoft Admin_srinivasarao.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\Peoplesoft resumes\\Peoplesoft Admin_Varkala Vikas.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\Peoplesoft resumes\\Peoplesoft Admin_Vinod Akkala.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\Peoplesoft resumes\\PeopleSoft DBA_Ganesh Alladi.docx',
# ...

# %%
def readtxt(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)

# %%
li=[]
for filename in all_files:
    dummy_1=readtxt(filename)
    li.append(dummy_1)

# %%
df2=pd.DataFrame()

# %%
for files in all_files:
    print(files)
    df2["cv"]=li
# Out:
# C:\Users\q\Desktop\Resumes\Peoplesoft resumes\Peoplesoft Admin_AnubhavSingh.docx
# C:\Users\q\Desktop\Resumes\Peoplesoft resumes\Peoplesoft Admin_G Ananda Rayudu.docx
# C:\Users\q\Desktop\Resumes\Peoplesoft resumes\Peoplesoft Admin_Gangareddy.docx
# C:\Users\q\Desktop\Resumes\Peoplesoft resumes\Peoplesoft Admin_Murali.docx
# C:\Users\q\Desktop\Resumes\Peoplesoft resumes\Peoplesoft Admin_Priyanka Ramadoss.docx
# C:\Users\q\Desktop\Resumes\Peoplesoft resumes\Peoplesoft Admin_SirazuddinMohammad.docx
# C:\Users\q\Desktop\Resumes\Peoplesoft resumes\Peoplesoft Admin_srinivasarao.docx
# C:\Users\q\Desktop\Resumes\Peoplesoft resumes\Peoplesoft Admin_Varkala Vikas.docx
# C:\Users\q\Desktop\Resumes\Peoplesoft resumes\Peoplesoft Admin_Vinod Akkala.docx
# C:\Users\q\Desktop\Resumes\Peoplesoft resumes\PeopleSoft DBA_Ganesh Alladi.docx
# C:\Users\q\Desktop\Resumes\Peoplesoft resumes\PeopleSoft DBA_Vivekanand Sayana.docx
# ...

# %%
label_list=[]
for i in range (len(all_files)):
    label="Peoplesoft"
    label_list.append(label)

# %%
df2["label"]=label_list

# %%
df2
# Out:
#                                                    cv       label
# 0     Anubhav Kumar Singh\t\t\n\n  To work in a gl...  Peoplesoft
# 1   \n\n\n\n\n\n\t\n\nProfile Summary:\t\t\t\t\t\t...  Peoplesoft
# 2   PeopleSoft Database Administrator\n           ...  Peoplesoft
# 3   Murali\n\nExperience Summary \n\nI have 6 year...  Peoplesoft
# 4   Priyanka Ramadoss\n61/46, MountPleasant, \nCoo...  Peoplesoft
# 5   \n\n\n\n\n\n\n\n\n\n\n\n\n\nPROFILE SUMMARY\n\...  Peoplesoft
# 6   PEOPLESOFT Administrator\n\n\nSRINIVAS.K \t\t\...  Peoplesoft
# 7    PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...  Peoplesoft
# 8   Vinod Akkala                                  ...  Peoplesoft
# 9    PeopleSoft Admin/PeopleSoft DBA\n\nGanesh All...  Peoplesoft
# 10  PeopleSoft Administration\n \nVivekanand Sayan...  Peoplesoft
# 11  Arun Venu\n\n  EXPERIENCE SUMMARY\t\n\nExperie...  Peoplesoft
# 12  \n\n\n\n\nExperience Summary\n4.1 years- Exper...  Peoplesoft
# ...

# %% [markdown]
# # For Workday Resumes

# %%
path=r'C:\Users\q\Desktop\Resumes\workday resumes'
all_files=glob.glob(path + "/*.docx")
all_files
# Out:
# ['C:\\Users\\q\\Desktop\\Resumes\\workday resumes\\ChinnaSubbarayuduM_Hexaware.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\workday resumes\\Gopi Krishna_Hexaware.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\workday resumes\\Hari Krishna M_Hexaware.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\workday resumes\\Harikrishna Akula_Hexaware.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\workday resumes\\Hima Mendu_Hexaware.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\workday resumes\\Himaja G_(Hexaware).docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\workday resumes\\J. Sumanth Royal_Hexaware.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\workday resumes\\Jyotiverma_Heaware.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\workday resumes\\Madeeswar A_Hexaware.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\workday resumes\\MooraboyinaGuravaiah_Hexaware.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\workday resumes\\Naresh Babu Cherukuri_Hexaware.docx',
# ...

# %%
def readtxt(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)

# %%
li=[]
for filename in all_files:
    dummy_1=readtxt(filename)
    li.append(dummy_1)

# %%
df3=pd.DataFrame()

# %%
for files in all_files:
    print(files)
    df3["cv"]=li
# Out:
# C:\Users\q\Desktop\Resumes\workday resumes\ChinnaSubbarayuduM_Hexaware.docx
# C:\Users\q\Desktop\Resumes\workday resumes\Gopi Krishna_Hexaware.docx
# C:\Users\q\Desktop\Resumes\workday resumes\Hari Krishna M_Hexaware.docx
# C:\Users\q\Desktop\Resumes\workday resumes\Harikrishna Akula_Hexaware.docx
# C:\Users\q\Desktop\Resumes\workday resumes\Hima Mendu_Hexaware.docx
# C:\Users\q\Desktop\Resumes\workday resumes\Himaja G_(Hexaware).docx
# C:\Users\q\Desktop\Resumes\workday resumes\J. Sumanth Royal_Hexaware.docx
# C:\Users\q\Desktop\Resumes\workday resumes\Jyotiverma_Heaware.docx
# C:\Users\q\Desktop\Resumes\workday resumes\Madeeswar A_Hexaware.docx
# C:\Users\q\Desktop\Resumes\workday resumes\MooraboyinaGuravaiah_Hexaware.docx
# C:\Users\q\Desktop\Resumes\workday resumes\Naresh Babu Cherukuri_Hexaware.docx
# C:\Users\q\Desktop\Resumes\workday resumes\P V Sai Krishna_ Hexaware.docx
# C:\Users\q\Desktop\Resumes\workday resumes\Punugoti Swetha_Hexaware.docx
# ...

# %%
label_list=[]
for i in range (len(all_files)):
    label="Workday"
    label_list.append(label)

# %%
df3["label"]=label_list

# %%
df3
# Out:
#                                                    cv    label
# 0   Chinna Subbarayudu M\nDOB: 06th March 1994\nNa...  Workday
# 1   \t\n\n\nName         : Gopi Krishna Reddy\n\t\...  Workday
# 2   Hari Krishna M\n\n\nSummary:\nA result oriente...  Workday
# 3   Harikrishna Akula                             ...  Workday
# 4   HIMA.MENDU\n  \n\nCareer Objective\nTo continu...  Workday
# 5                                         \n      ...  Workday
# 6   \t\t\t\t\t\t\tName:\tJ. Sumanth Royal.\n\t\nPR...  Workday
# 7   \n\nJYOTI VERMA\t\t\t\t\t\n\n\n\n3 years of Ex...  Workday
# 8   \t\t\t\t\tMadeeswar A\n\t\n\t\nPROFILE SUMMARY...  Workday
# 9   \n\nMooraboyina Guravaiah\nWorkday Integration...  Workday
# 10  Name\t: Naresh Babu Cherukuri\n\nObjective:\nT...  Workday
# 11  VENKATA SAIKRISHNA\n Workday Consultant\n\n\nP...  Workday
# 12  \n\n\n3.3 years of IT experience as Workday HC...  Workday
# 13  Rahul  (Techno Functional Consultant)  \nProfe...  Workday
# ...

# %% [markdown]
# # For React JS Developer

# %%
path=r'C:\Users\q\Desktop\Resumes'
all_files=glob.glob(path + "/*.docx") 
all_files
# Out:
# ['C:\\Users\\q\\Desktop\\Resumes\\React Developer_Deepakreddy.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\React Developer_Haripriya.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\React Developer_Kamalakar Reddy.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\React Developer_Naveen sadhu.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\React Developer_PavasGoswami.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\React Developer_Pragnya.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\React Developer_Sarala Madasu-converted.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\React Developer_Thirupathiamma.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\React Developer_Vinay Reddy.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\React Dev_Krishna Kanth.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\React Dev_Krishna Kanth_Musquare Technologies.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\React JS Developer_AnjaniPriyadarshini.docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\React JS Developer_KotaniDurgaprasad[3_1] (1)-converted.docx',
# ...

# %%
def readtxt(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)

# %%
li=[]
for filename in all_files:
    dummy_1= readtxt(filename)
    li.append(dummy_1)

# %%
df4=pd.DataFrame()

# %%
for files in all_files:
    print(files)
    df4["cv"]=li
# Out:
# C:\Users\q\Desktop\Resumes\React Developer_Deepakreddy.docx
# C:\Users\q\Desktop\Resumes\React Developer_Haripriya.docx
# C:\Users\q\Desktop\Resumes\React Developer_Kamalakar Reddy.docx
# C:\Users\q\Desktop\Resumes\React Developer_Naveen sadhu.docx
# C:\Users\q\Desktop\Resumes\React Developer_PavasGoswami.docx
# C:\Users\q\Desktop\Resumes\React Developer_Pragnya.docx
# C:\Users\q\Desktop\Resumes\React Developer_Sarala Madasu-converted.docx
# C:\Users\q\Desktop\Resumes\React Developer_Thirupathiamma.docx
# C:\Users\q\Desktop\Resumes\React Developer_Vinay Reddy.docx
# C:\Users\q\Desktop\Resumes\React Dev_Krishna Kanth.docx
# C:\Users\q\Desktop\Resumes\React Dev_Krishna Kanth_Musquare Technologies.docx
# C:\Users\q\Desktop\Resumes\React JS Developer_AnjaniPriyadarshini.docx
# C:\Users\q\Desktop\Resumes\React JS Developer_KotaniDurgaprasad[3_1] (1)-converted.docx
# C:\Users\q\Desktop\Resumes\React JS Developer_Venkatalakshmi (1)-converted.docx
# ...

# %%
df4
# Out:
#                                                    cv
# 0   Kanumuru Deepak Reddy\n\n\n\nCAREER OBJECTIVE:...
# 1   HARIPRIYA BATTINA \nExperience as UI Developer...
# 2   KAMALAKAR REDDY. A \nLinked In: https://www.li...
# 3   \nNaveen Sadhu\n\n\nTitle: software developer\...
# 4   \n\n\nPROFILE\nSearching for the opportunity t...
# 5    \nPRAGNYA PATTNAIK\n \n \n \n Expertise: \n \...
# 6   \n\n 204,Sri geethika prestige,road number 10...
# 7   \n\nThirupathamma Balla\n\nSUMMARY:\n\n2.8 yea...
# 8   Maryala Vinay Reddy\n\nProfessional Summary:\t...
# 9   \nUi-Developer/ React JS Developer \nNAME: KRI...
# 10  \nUi-Developer/ React JS Developer \nNAME: KRI...
# 11  CURRICULUM VITAE\n\n\n\n\nI hereby declare tha...
# 12  Kotani Durga Prasad\n\n\nObjective:\n\nAspiran...
# 13  Venkatalakshmi Pedireddy\nSoftware Developer\n...
# 14  KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...
# 15  MAREEDU LOKESH BABU\nPROFESSIONAL OVERVIEW\n  ...
# ...

# %%
label_list=" React JS Developer"

# %%
df4["label"]=label_list

# %%
df4
# Out:
#                                                    cv                label
# 0   Kanumuru Deepak Reddy\n\n\n\nCAREER OBJECTIVE:...   React JS Developer
# 1   HARIPRIYA BATTINA \nExperience as UI Developer...   React JS Developer
# 2   KAMALAKAR REDDY. A \nLinked In: https://www.li...   React JS Developer
# 3   \nNaveen Sadhu\n\n\nTitle: software developer\...   React JS Developer
# 4   \n\n\nPROFILE\nSearching for the opportunity t...   React JS Developer
# 5    \nPRAGNYA PATTNAIK\n \n \n \n Expertise: \n \...   React JS Developer
# 6   \n\n 204,Sri geethika prestige,road number 10...   React JS Developer
# 7   \n\nThirupathamma Balla\n\nSUMMARY:\n\n2.8 yea...   React JS Developer
# 8   Maryala Vinay Reddy\n\nProfessional Summary:\t...   React JS Developer
# 9   \nUi-Developer/ React JS Developer \nNAME: KRI...   React JS Developer
# 10  \nUi-Developer/ React JS Developer \nNAME: KRI...   React JS Developer
# ...

# %% [markdown]
# # For Internship

# %%
path=r'C:\Users\q\Desktop\Resumes\Internship'
all_files=glob.glob(path + "/*.docx") 
all_files
# Out:
# ['C:\\Users\\q\\Desktop\\Resumes\\Internship\\Internship_Ravali_Musquare Technologies (1).docx',
#  'C:\\Users\\q\\Desktop\\Resumes\\Internship\\Internship_Susovan Bag_Musquare Technologies.docx']

# %%
def readtxt(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)

# %%
li=[]
for filename in all_files:
    dummy_1= readtxt(filename)
    li.append(dummy_1)

# %%
df5=pd.DataFrame()

# %%
for files in all_files:
    print(files)
    df5["cv"]=li
# Out:
# C:\Users\q\Desktop\Resumes\Internship\Internship_Ravali_Musquare Technologies (1).docx
# C:\Users\q\Desktop\Resumes\Internship\Internship_Susovan Bag_Musquare Technologies.docx

# %%
label_list=" Internship"

# %%
df5['label']=label_list

# %%
df5
# Out:
#                                                   cv        label
# 0  Name: Ravali P \n\n                           ...   Internship
# 1    \nSUSOVAN  BAG   \nSeeking  a  challenging  ...   Internship

# %% [markdown]
# # Collecting all data.

# %%
data=df.append([df2,df3,df4,df5],ignore_index = True)
# Out:
# C:\Users\q\AppData\Local\Temp\ipykernel_7044\1503372402.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data=df.append([df2,df3,df4,df5],ignore_index = True)

# %%
data
# Out:
#                                                    cv                label
# 0   ANIL KUMAR MADDUKURI  \t\t\nSQL & MSBI Develop...        SQL Developer
# 1   \nAradhana Tripathi\n\nCurrent Location: Gachi...        SQL Developer
# 2   BUDDHA VAMSI                                  ...        SQL Developer
# 3   KAMBALLA PRADEEP                              ...        SQL Developer
# 4   \n\n\n Hyderabad\n\nNazeer Basha\nSQL and Pow...        SQL Developer
# ..                                                ...                  ...
# 73  \nPranish Sonone\n\t\n\n\n\n\nCareer summary:\...   React JS Developer
# 74  Ranga Gaganam  \n \n \nHaving 1+ years of succ...   React JS Developer
# 75  SHAIK ABDUL SHARUK   \n2 years’ Experience in ...   React JS Developer
# 76  Name: Ravali P \n\n                           ...           Internship
# 77    \nSUSOVAN  BAG   \nSeeking  a  challenging  ...           Internship
#
# [78 rows x 2 columns]

# %%
## Data is extracted carefully. Next step is Explotary data analysis.

# %% [markdown]
# # EDA

# %%
data
# Out:
#                                                    cv                label
# 0   ANIL KUMAR MADDUKURI  \t\t\nSQL & MSBI Develop...        SQL Developer
# 1   \nAradhana Tripathi\n\nCurrent Location: Gachi...        SQL Developer
# 2   BUDDHA VAMSI                                  ...        SQL Developer
# 3   KAMBALLA PRADEEP                              ...        SQL Developer
# 4   \n\n\n Hyderabad\n\nNazeer Basha\nSQL and Pow...        SQL Developer
# ..                                                ...                  ...
# 73  \nPranish Sonone\n\t\n\n\n\n\nCareer summary:\...   React JS Developer
# 74  Ranga Gaganam  \n \n \nHaving 1+ years of succ...   React JS Developer
# 75  SHAIK ABDUL SHARUK   \n2 years’ Experience in ...   React JS Developer
# 76  Name: Ravali P \n\n                           ...           Internship
# 77    \nSUSOVAN  BAG   \nSeeking  a  challenging  ...           Internship
#
# [78 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cv      78 non-null     object
#  1   label   78 non-null     object
# dtypes: object(2)
# memory usage: 1.3+ KB

# %%
data.isna().sum()
# Out:
# cv       0
# label    0
# dtype: int64

# %%
def preprocess(txt):
    txt=txt.lower()                                                           # convert all characters in the string to lower case
    txt = re.sub('[^a-zA-Z]', ' ', txt)                                           # remove non-english characters, punctuation and numbers
    txt = re.sub('http\S+\s*', ' ', txt)                                          # remove URLs
    txt = re.sub('RT|cc', ' ', txt)                                               # remove RT and cc
    txt = re.sub('#\S+', '', txt)                                                 # remove hashtags
    txt = re.sub('@\S+', '  ', txt)                                               # remove mentions
    txt = re.sub('\s+', ' ', txt)                                                 # remove extra whitespace
    txt = nltk.tokenize.word_tokenize(txt)                                        # tokenize word
    txt = [w for w in txt if not w in nltk.corpus.stopwords.words('english')]     # remove stop words
    return ' '.join(txt)                                                          # stemming

# %%
data['cv']=data['cv'].apply(lambda w: preprocess(w))

# %%
data.to_csv('Resume.csv', index=False)

# %%
data
# Out:
#                                                    cv  label
# 0   anil kumar maddukuri sql msbi developer summar...      3
# 1   aradhana tripathi current location gachibowli ...      3
# 2   buddha vamsi career objective years experience...      3
# 3   kamballa pradeep synopsis looking forward aspi...      3
# 4   hyderabad nazeer basha sql power bi developer ...      3
# ..                                                ...    ...
# 73  pranish sonone career summary experience years...      1
# 74  ranga gaganam years su essful experience phase...      1
# 75  shaik abdul sharuk years experience wipro care...      1
# 76  name ravali p curriculum vitae specialization ...      0
# 77  susovan bag seeking challenging position field...      0
#
# [78 rows x 2 columns]

# %%
import string
from nltk.corpus import stopwords
oneSetOfStopWords = set(stopwords.words('english')+['``',"''"])
totalWords =[]
Sentences = data['cv'].values
cleanedSentences = ""
for records in Sentences:
    cleanedSentences += records
    requiredWords = nltk.word_tokenize(records)
    for word in requiredWords:
        if word not in oneSetOfStopWords and word not in string.punctuation:
            totalWords.append(word)
    
wordfreqdist = nltk.FreqDist(totalWords)
mostcommon = wordfreqdist.most_common(100)
print(mostcommon)
# Out:
# [('experience', 560), ('peoplesoft', 395), ('using', 369), ('application', 368), ('workday', 367), ('server', 327), ('reports', 310), ('data', 304), ('project', 265), ('business', 255), ('sql', 234), ('process', 222), ('database', 216), ('web', 203), ('knowledge', 202), ('worked', 189), ('integrations', 175), ('involved', 173), ('integration', 169), ('like', 165), ('client', 163), ('system', 162), ('good', 161), ('creating', 157), ('development', 153), ('support', 152), ('working', 150), ('hcm', 150), ('servers', 149), ('tools', 145), ('skills', 144), ('various', 142), ('technical', 139), ('testing', 139), ('report', 138), ('people', 133), ('team', 133), ('design', 130), ('created', 128), ('issues', 128), ('production', 128), ('react', 123), ('responsibilities', 121), ('security', 121), ('environment', 120), ('management', 118), ('oracle', 116), ('domains', 115), ('eib', 115), ('custom', 114), ('services', 112), ('work', 112), ('scheduler', 109), ('developed', 106), ('test', 106), ('
# ...

# %%
freq_word=pd.DataFrame(mostcommon)
freq_word.columns=['word','count']
freq_word[0:10]
# Out:
#           word  count
# 0   experience    560
# 1   peoplesoft    395
# 2        using    369
# 3  application    368
# 4      workday    367
# 5       server    327
# 6      reports    310
# 7         data    304
# 8      project    265
# 9     business    255

# %%
figsize=(12, 6)
colors='red','green','blue','pink','black','voilet','yellow'
freq_word[0:20].plot(x='word',kind='bar' )
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='word', data=freq_word[0:20])
# Out:
# <AxesSubplot:xlabel='word', ylabel='count'>

# %% [markdown]
# # Bi-Gram

# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

# %%
def get_top_n2_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(2,2),  
            max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]

# %%
top2_words = get_top_n2_words(data['cv'], n=200) #top 200
top2_df = pd.DataFrame(top2_words)
top2_df.columns=["Bi-gram", "Freq"]
top2_df.head(20)
# Out:
#                   Bi-gram  Freq
# 0       process scheduler   106
# 1              sql server   103
# 2      application server    89
# 3                react js    87
# 4          server domains    70
# 5          custom reports    65
# 6       calculated fields    62
# 7              web server    61
# 8          workday studio    61
# 9            people tools    59
# 10              till date    57
# 11            workday hcm    57
# 12       years experience    55
# 13               html css    55
# 14         good knowledge    52
# 15  experience peoplesoft    49
# 16       hands experience    47
# 17       business process    46
# 18       technical skills    45
# 19     integration broker    44

# %%
import matplotlib.pyplot as plt
import seaborn as sns
top20_bigram = top2_df.iloc[0:20,:]
fig = plt.figure(figsize = (10, 5))
plot=sns.barplot(x=top20_bigram["Bi-gram"],y=top20_bigram["Freq"])
plot.set_xticklabels(rotation=45,labels = top20_bigram["Bi-gram"])
# Out:
# [Text(0, 0, 'process scheduler'),
#  Text(1, 0, 'sql server'),
#  Text(2, 0, 'application server'),
#  Text(3, 0, 'react js'),
#  Text(4, 0, 'server domains'),
#  Text(5, 0, 'custom reports'),
#  Text(6, 0, 'calculated fields'),
#  Text(7, 0, 'web server'),
#  Text(8, 0, 'workday studio'),
#  Text(9, 0, 'people tools'),
#  Text(10, 0, 'till date'),
#  Text(11, 0, 'workday hcm'),
#  Text(12, 0, 'years experience'),
#  Text(13, 0, 'html css'),
#  Text(14, 0, 'good knowledge'),
#  Text(15, 0, 'experience peoplesoft'),
#  Text(16, 0, 'hands experience'),
#  Text(17, 0, 'business process'),
#  Text(18, 0, 'technical skills'),
#  Text(19, 0, 'integration broker')]

# %% [markdown]
# # Tri-Gram

# %%
def get_top_n3_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(3,3), 
           max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]

# %%
top3_words = get_top_n3_words(data['cv'], n=200)
top3_df = pd.DataFrame(top3_words)
top3_df.columns=["Tri-gram", "Freq"]

# %%
top3_df
# Out:
#                               Tri-gram  Freq
# 0           application server domains    37
# 1            process scheduler servers    36
# 2               server domains process    35
# 3            domains process scheduler    35
# 4                   web server domains    27
# ..                                 ...   ...
# 195             download updates fixes     7
# 196     troubleshooting various issues     7
# 197               best knowledge place     7
# 198  peoplesoft database administrator     7
# 199     configuration setup management     7
#
# [200 rows x 2 columns]

# %%
import seaborn as sns
top20_trigram = top3_df.iloc[0:20,:]
fig = plt.figure(figsize = (10, 5))
plot=sns.barplot(x=top20_trigram["Tri-gram"],y=top20_trigram["Freq"])
plot.set_xticklabels(rotation=45,labels = top20_trigram["Tri-gram"])
# Out:
# [Text(0, 0, 'application server domains'),
#  Text(1, 0, 'process scheduler servers'),
#  Text(2, 0, 'server domains process'),
#  Text(3, 0, 'domains process scheduler'),
#  Text(4, 0, 'web server domains'),
#  Text(5, 0, 'servers web servers'),
#  Text(6, 0, 'peoplesoft internet architecture'),
#  Text(7, 0, 'domains web server'),
#  Text(8, 0, 'true best knowledge'),
#  Text(9, 0, 'html css javascript'),
#  Text(10, 0, 'servers process scheduler'),
#  Text(11, 0, 'summary years experience'),
#  Text(12, 0, 'application servers web'),
#  Text(13, 0, 'process scheduler server'),
#  Text(14, 0, 'server process scheduler'),
#  Text(15, 0, 'ms sql server'),
#  Text(16, 0, 'professional summary years'),
#  Text(17, 0, 'process scheduler domains'),
#  Text(18, 0, 'internet architecture pia'),
#  Text(19, 0, 'load balancing application')]

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer 
wn = WordNetLemmatizer() 
lem_words=[]
for word in wordfreqdist:
    word=wn.lemmatize(word)
    lem_words.append(word)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\q\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\q\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# # WordCloud

# %%
wc = WordCloud().generate(cleanedSentences)
plt.figure(figsize=(10,10))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
labels=(data['label'].unique())
labels
# Out:
# array([3, 2, 4, 1, 0])

# %%
data_labels = [data[data['label'] == label].loc[:, ['cv', 'label']] for label in labels]
data_labels
# Out:
# [                                                   cv  label
#  0   anil kumar maddukuri sql msbi developer summar...      3
#  1   aradhana tripathi current location gachibowli ...      3
#  2   buddha vamsi career objective years experience...      3
#  3   kamballa pradeep synopsis looking forward aspi...      3
#  4   hyderabad nazeer basha sql power bi developer ...      3
#  5   resume name neeraj mishra year month experienc...      3
#  6   sql developer name bandi prem sai willing work...      3
#  7   sql server developer priyanka l professional s...      3
#  8   sql server developer p syam kumar professional...      3
#  9   raju pavana kumari professional summary years ...      3
#  10  resume ramalakshmi k career objective professi...      3
#  11  name ramesh career objective contribute organi...      3
#  12  career objective rewarding opportunity growth ...      3
#  13  b vinod kumar objective willing work challengi...      3,
# ...

# %%
data['label'].value_counts().sort_index().plot(kind='bar', figsize=(12, 6))
plt.show()

# %% [markdown]
# # WordCloud For all Categories

# %%
def wordcloud(df):
    txt = ' '.join(txt for txt in df['cv'])
    wordcloud = WordCloud(
        height=2000,
        width=4000,
        colormap=WORDCLOUD_COLOR_MAP
    ).generate(txt)

    return wordcloud

# %%
# for other theme, please run: mpl.pyplot.style.available
PLOT_PALETTE = 'tableau-colorblind10'
# for other color map, please run: mpl.pyplot.colormaps()
WORDCLOUD_COLOR_MAP = 'tab10_r'
plt.style.use(PLOT_PALETTE)
# %matplotlib inline

# %%
plt.figure(figsize=(32, 28))

for i,label in enumerate(labels):
    wc = wordcloud(data_labels[i])

    plt.subplot(5, 5, i + 1).set_title(label)
    plt.imshow(wc)
    plt.axis('off')
    plt.plot()

plt.show()
plt.close()

# %%
def wordfreq(df):
    count = data['cv'].str.split(expand=True).stack().value_counts().reset_index()
    count.columns = ['Word', 'Frequency']

    return count.head(10)

# %%
fig = plt.figure(figsize=(32, 64))

for i,label in enumerate(labels):
    wf = wordfreq(data_labels[i])

    fig.add_subplot(5, 5, i + 1).set_title(label)
    plt.bar(wf['Word'], wf['Frequency'])
    plt.ylim(0, 500)

plt.show()
plt.close()

# %%
from sklearn.preprocessing import LabelEncoder

var_mod = ['label']
le = LabelEncoder()
for i in var_mod:
    data[i] = le.fit_transform(data[i])

# %%
data
# Out:
#                                                    cv  label
# 0   anil kumar maddukuri sql msbi developer summar...      3
# 1   aradhana tripathi current location gachibowli ...      3
# 2   buddha vamsi career objective years experience...      3
# 3   kamballa pradeep synopsis looking forward aspi...      3
# 4   hyderabad nazeer basha sql power bi developer ...      3
# ..                                                ...    ...
# 73  pranish sonone career summary experience years...      1
# 74  ranga gaganam years su essful experience phase...      1
# 75  shaik abdul sharuk years experience wipro care...      1
# 76  name ravali p curriculum vitae specialization ...      0
# 77  susovan bag seeking challenging position field...      0
#
# [78 rows x 2 columns]

# %%
data.label.value_counts()
# Out:
# 4    21
# 1    21
# 2    20
# 3    14
# 0     2
# Name: label, dtype: int64

# %%
import seaborn as sns
sns.pairplot(data = data)

# %%
plt.figure(figsize=(10,10))
plt.xticks()
sns.countplot(y="label", data=data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='label'>

# %%
labelcount=data.label.value_counts().reset_index()['label']
labelcount
# Out:
# 0    21
# 1    21
# 2    20
# 3    14
# 4     2
# Name: label, dtype: int64

# %%
from matplotlib.gridspec import GridSpec
plt.figure(1, figsize=(20,20))
the_grid = GridSpec(2, 2)
plt.subplot(the_grid[0, 1], aspect=1, title='LABEL DISTRIBUTION')
source_pie = plt.pie(labelcount, labels=labels, autopct='%1.1f%%', shadow=True)

# %%
freq_dist = nltk.FreqDist(lem_words)
plt.subplots(figsize=(20,12))
freq_dist.plot(30)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack

# %%
requiredText = data['cv'].values
requiredTarget = data['label'].values

word_vectorizer = TfidfVectorizer(
    sublinear_tf=True,
    stop_words='english')
word_vectorizer.fit(requiredText)
WordFeatures = word_vectorizer.transform(requiredText)

print ("Feature completed .....")
# Out:
# Feature completed .....

# %%
WordFeatures
# Out:
# <78x3923 sparse matrix of type '<class 'numpy.float64'>'
# 	with 17445 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Split The Data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(WordFeatures, requiredTarget, random_state=30, test_size=0.20, shuffle = True, stratify=requiredTarget)
X_train.shape, X_test.shape
# Out:
# ((62, 3923), (16, 3923))

# %% [markdown]
# # Model Building

# %% [raw]
# ######
# For model building we used following algorithms..
# 1.Naive Bays
# 2.Random Forest Classifier
# 3.Logistic Regression
# 4.SVM
# 5.Decision Tree Classifier
# 6.KNeigbhor Classifier
# 7. XGB Classifier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,roc_auc_score,accuracy_score,classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.multiclass import OneVsRestClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score
from pandas.plotting import scatter_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import plotly as py
from plotly.offline import init_notebook_mode, iplot
#init_notebook_mode(connected=True)
import plotly.graph_objs as go

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1.Navie Bayes

# %%
clf =MultinomialNB(alpha=1, fit_prior=False, class_prior=None).fit(X_train, y_train)
prediction = clf.predict(X_test)
print('Accuracy of MultinomialNB Classifier on training set: {:.2f}'.format(clf.score(X_train, y_train)))
print('Accuracy of MultinomialNB Classifier on test set: {:.2f}'.format(clf.score(X_test, y_test)))
print("Classification report for classifier %s:\n%s\n" % (clf, metrics.classification_report(y_test, prediction)))
mnb_score = clf.score(X_test, y_test)
mnb_cm = confusion_matrix(y_test, prediction)
# Out:
# Accuracy of MultinomialNB Classifier on training set: 1.00
# Accuracy of MultinomialNB Classifier on test set: 0.94
# Classification report for classifier MultinomialNB(alpha=1, fit_prior=False):
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.80      1.00      0.89         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         4
#
#     accuracy                           0.94        16
#    macro avg       0.76      0.80      0.78        16
# weighted avg       0.89      0.94      0.91        16

# %%
clf =GaussianNB().fit(X_train.toarray(), y_train)
prediction = clf.predict(X_test.toarray())
print('Accuracy of MultinomialNB Classifier on training set: {:.2f}'.format(clf.score(X_train.toarray(), y_train)))
print('Accuracy of MultinomialNB Classifier on test set: {:.2f}'.format(clf.score(X_test.toarray(), y_test)))
print("Classification report for classifier %s:\n%s\n" % (clf, metrics.classification_report(y_test, prediction)))
gnb_score = clf.score(X_test.toarray(), y_test)
gnb_cm = confusion_matrix(y_test, prediction)
# Out:
# Accuracy of MultinomialNB Classifier on training set: 1.00
# Accuracy of MultinomialNB Classifier on test set: 0.81
# Classification report for classifier GaussianNB():
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.80      1.00      0.89         4
#            2       1.00      0.75      0.86         4
#            3       1.00      0.67      0.80         3
#            4       0.67      1.00      0.80         4
#
#     accuracy                           0.81        16
#    macro avg       0.69      0.68      0.67        16
# weighted avg       0.80      0.81      0.79        16

# %% [markdown]
# # 2.Random Forest Classifier

# %%
rf =RandomForestClassifier(n_estimators=100,criterion='entropy',max_depth=3,max_features='auto',random_state=None,
 class_weight="balanced")
rf.fit(X_train, y_train)
rf_prediction = rf.predict(X_test)
rf_score = rf.score(X_test, y_test)
print("Random Forest Classification Train Accuracy: {}%".format(round(rf.score(X_train,y_train)*100,2)))
print("Random Forest Classification Test Accuracy: {}%".format(round(rf.score(X_test,y_test)*100,2)))
rf_cm = confusion_matrix(y_test, rf_prediction)
print("Classification Report:\n")
print(classification_report(y_test, rf_prediction))
# Out:
# Random Forest Classification Train Accuracy: 100.0%
# Random Forest Classification Test Accuracy: 93.75%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.80      1.00      0.89         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         4
#
#     accuracy                           0.94        16
#    macro avg       0.76      0.80      0.78        16
# weighted avg       0.89      0.94      0.91        16

# %% [markdown]
# # 3.Logistic Regression

# %%
lr = LogisticRegression(class_weight ='balanced')
lr.fit(X_train, y_train)
lr_prediction = lr.predict(X_test)
lr_score = lr.score(X_test,y_test)
print("Logistic Regression Train Accuracy: {}%".format(round(lr.score(X_train,y_train)*100,2)))
print("Logistic Regression Test Accuracy: {}%".format(round(lr.score(X_test,y_test)*100,2)))
lr_cm = confusion_matrix(y_test, lr_prediction)
print("Classification Report:\n")
print(classification_report(y_test, lr_prediction))
# Out:
# Logistic Regression Train Accuracy: 100.0%
# Logistic Regression Test Accuracy: 93.75%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.80      1.00      0.89         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         4
#
#     accuracy                           0.94        16
#    macro avg       0.76      0.80      0.78        16
# weighted avg       0.89      0.94      0.91        16

# %% [markdown]
# # 4.Support Vectore Machine

# %%
svm = SVC(C=1.0,kernel='linear',degree=3,gamma='scale',class_weight ='balanced')
svm.fit(X_train, y_train)
svm_prediction = svm.predict(X_test)
svm_score = svm.score(X_test, y_test)
print("SVM Classification Train Accuracy: {}%".format(round(svm.score(X_train,y_train)*100,2)))
print("SVM Classification Test Accuracy: {}%".format(round(svm.score(X_test,y_test)*100,2)))
svm_cm = confusion_matrix(y_test, svm_prediction)

print("Classification Report:\n")

print(classification_report(y_test, svm_prediction))
# Out:
# SVM Classification Train Accuracy: 100.0%
# SVM Classification Test Accuracy: 93.75%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.80      1.00      0.89         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         4
#
#     accuracy                           0.94        16
#    macro avg       0.76      0.80      0.78        16
# weighted avg       0.89      0.94      0.91        16

# %% [markdown]
# # 5. KNeigbhor Classifier

# %%
knn = KNeighborsClassifier(n_neighbors=1, weights='uniform',p=2,metric='minkowski',algorithm='brute')
knn.fit(X_train, y_train)
knn_prediction = knn.predict(X_test)
knn_score = knn.score(X_test, y_test)
print("KNN Classification Train Accuracy: {}%".format(round(knn.score(X_train,y_train)*100,2)))
print("KNN Classification Test Accuracy: {}%".format(round(knn.score(X_test,y_test)*100,2)))
knn_cm = confusion_matrix(y_test, knn_prediction)

print('Classification Report:\n')

print(classification_report(y_test, knn_prediction))
# Out:
# KNN Classification Train Accuracy: 100.0%
# KNN Classification Test Accuracy: 93.75%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.80      1.00      0.89         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         4
#
#     accuracy                           0.94        16
#    macro avg       0.76      0.80      0.78        16
# weighted avg       0.89      0.94      0.91        16

# %%
#Find Best K Value

score_list = []
for each in range(1,30):
    knn2 =OneVsRestClassifier(KNeighborsClassifier(n_neighbors=each, weights='uniform',p=2,metric='minkowski',algorithm='brute'))
    knn2.fit(X_train, y_train)
    score_list.append(knn2.score(X_test, y_test))
plt.plot(range(1,30), score_list)
plt.xlabel("K Values")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# # XGB Classifier

# %% [markdown]
# # 7.AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier
ab_clf = AdaBoostClassifier()
ab_clf.fit(X_train, y_train)
prediction = ab_clf.predict(X_test)
print('Accuracy of AdaBoost Classifier on training set: {:.4f}%'.format(ab_clf.score(X_train, y_train)*100))
print('Accuracy of AdaBoost Classifier on test set    : {:.4f}%'.format(ab_clf.score(X_test, y_test)*100))
ab_cm=confusion_matrix(y_test,prediction)
ab_score=ab_clf.score(X_test, y_test)
# Out:
# Accuracy of AdaBoost Classifier on training set: 100.0000%
# Accuracy of AdaBoost Classifier on test set    : 87.5000%

# %%
print("\n Classification report for AdaBoost Classifier %s:\n%s\n" % (ab_clf, metrics.classification_report(y_test, prediction)))
# Out:
#  Classification report for AdaBoost Classifier AdaBoostClassifier():
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      1.00      0.80         4
#            2       1.00      0.75      0.86         4
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         4
#
#     accuracy                           0.88        16
#    macro avg       0.73      0.75      0.73        16
# weighted avg       0.85      0.88      0.85        16

# %% [markdown]
# # 8. GradientBoosting Classifier

# %%
gb_clf = GradientBoostingClassifier()
gb_clf.fit(X_train, y_train)
prediction = gb_clf.predict(X_test)
print('Accuracy of GradientBoosting Classifier on training set: {:.4f}'.format(gb_clf.score(X_train, y_train)))
print('Accuracy of GradientBoosting Classifier on test set    : {:.4f}'.format(gb_clf.score(X_test, y_test)))
gb_cm=confusion_matrix(y_test,prediction)
gb_score=gb_clf.score(X_test, y_test)
# Out:
# Accuracy of GradientBoosting Classifier on training set: 1.0000
# Accuracy of GradientBoosting Classifier on test set    : 0.8750

# %%
print("\n Classification report for GradientBoosting Classifier %s:\n%s\n" % (gb_clf, metrics.classification_report(y_test, prediction)))
# Out:
#  Classification report for GradientBoosting Classifier GradientBoostingClassifier():
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.80      1.00      0.89         4
#            2       1.00      0.75      0.86         4
#            3       1.00      1.00      1.00         3
#            4       0.80      1.00      0.89         4
#
#     accuracy                           0.88        16
#    macro avg       0.72      0.75      0.73        16
# weighted avg       0.84      0.88      0.85        16

# %%
# !pip install lightgbm

# %% [markdown]
# # 9.XGB Classifier

# %%
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
xgb_clf = XGBClassifier()
xgb_clf.fit(X_train, y_train)
prediction = xgb_clf.predict(X_test)
print('Accuracy of XtremeGradientBoosting Classifier on training set: {:.4f}'.format(xgb_clf.score(X_train, y_train)))
print('Accuracy of XtremeGradientBoosting Classifier on test set    : {:.4f}'.format(xgb_clf.score(X_test, y_test)))
xgb_cm=confusion_matrix(y_test,prediction)
xgb_score=xgb_clf.score(X_test, y_test)
# Out:
# Accuracy of XtremeGradientBoosting Classifier on training set: 1.0000
# Accuracy of XtremeGradientBoosting Classifier on test set    : 0.8125

# %%
print("\n Classification report for XtremeGradientBoosting Classifier %s:\n%s\n" % (xgb_clf, metrics.classification_report(y_test, prediction)))
# Out:
#  Classification report for XtremeGradientBoosting Classifier XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...):
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.75      0.75      0.75         4
# ...

# %% [markdown]
# # 10.LGB Classifier

# %%
lgb_clf = LGBMClassifier()
lgb_clf.fit(X_train, y_train)
prediction = lgb_clf.predict(X_test)
print('Accuracy of LightGradientBoosting Classifier on training set: {:.4f}'.format(lgb_clf.score(X_train, y_train)))
print('Accuracy of LightGradientBoosting Classifier on test set    : {:.4f}'.format(lgb_clf.score(X_test, y_test)))
lgb_cm=confusion_matrix(y_test,prediction)
lgb_score=lgb_clf.score(X_test, y_test)
# Out:
# Accuracy of LightGradientBoosting Classifier on training set: 1.0000
# Accuracy of LightGradientBoosting Classifier on test set    : 0.9375

# %%
print("\n Classification report for LightGradientBoosting Classifier %s:\n%s\n" % (lgb_clf, metrics.classification_report(y_test, prediction)))
# Out:
#  Classification report for LightGradientBoosting Classifier LGBMClassifier():
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.80      1.00      0.89         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         4
#
#     accuracy                           0.94        16
#    macro avg       0.76      0.80      0.78        16
# weighted avg       0.89      0.94      0.91        16

# %% [markdown]
# # 11.DecisionTree Classifier

# %%
dt = DecisionTreeClassifier(criterion='entropy',class_weight = "balanced",splitter='best',max_depth=None)
dt.fit(X_train, y_train)
dt_prediction = dt.predict(X_test)
dt_score = dt.score(X_test, y_test)
print("Decision Tree Classification Train Accuracy: {}%".format(round(dt.score(X_train,y_train)*100,2)))
print("Decision Tree Classification Test Accuracy: {}%".format(round(dt.score(X_test,y_test)*100,2)))
dt_cm = confusion_matrix(y_test, dt_prediction)

print("Classification Report:\n")

print(classification_report(y_test, dt_prediction))
# Out:
# Decision Tree Classification Train Accuracy: 100.0%
# Decision Tree Classification Test Accuracy: 93.75%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.80      1.00      0.89         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         4
#
#     accuracy                           0.94        16
#    macro avg       0.76      0.80      0.78        16
# weighted avg       0.89      0.94      0.91        16

# %% [markdown]
# # Accuracy Comparision

# %%
accuracy=pd.DataFrame()

# %%
accuracy['Model']=[' Multinomi Naive Bayes',"Gaussian Naive Bayes",'RandomForest Classifier','Logistic Regression','Support Vectore Machine','KNeigbhor Classifier','AdaBoosting Classifier','GradiantBoosting Classifier','XGB Classifier','LGB Classifier','DecisionTree Classifier']

# %%
accuracy['Accuracy']=[mnb_score,gnb_score,rf_score,lr_score,svm_score,knn_score,ab_score,gb_score,xgb_score,lgb_score,dt_score]

# %%
accuracy
# Out:
#                           Model  Accuracy
# 0         Multinomi Naive Bayes    0.9375
# 1          Gaussian Naive Bayes    0.8125
# 2       RandomForest Classifier    0.9375
# 3           Logistic Regression    0.9375
# 4       Support Vectore Machine    0.9375
# 5          KNeigbhor Classifier    0.9375
# 6        AdaBoosting Classifier    0.8750
# 7   GradiantBoosting Classifier    0.8750
# 8                XGB Classifier    0.8125
# 9                LGB Classifier    0.9375
# 10      DecisionTree Classifier    0.9375

# %% [markdown]
# # Confusion Matrics Heatmap

# %%
plt.figure(figsize=(20,15))
plt.suptitle("Confusion Matrixes", fontsize=18)

plt.subplot(2,3,1)
plt.title(" Multinomi NaiveBayes Classification")
sns.heatmap(mnb_cm, cbar=False, annot=True, cmap="rainbow", fmt="d")

plt.subplot(2,3,2)
plt.title("Gaussian NaiveBayes Classification")
sns.heatmap(gnb_cm, cbar=False, annot=True, cmap="rainbow", fmt="d")

plt.subplot(2,3,3)
plt.title("RandomForest Classification")
sns.heatmap(rf_cm, cbar=False, annot=True, cmap="rainbow", fmt="d")


plt.subplot(2,3,4)
plt.title("Logistic Regression")
sns.heatmap(lr_cm, cbar=False, annot=True, cmap="rainbow", fmt="d")

plt.subplot(2,3,5)
plt.title("SVM Classification")
sns.heatmap(svm_cm, cbar=False, annot=True, cmap="rainbow", fmt="d")


plt.subplot(2,3,6)
plt.title("KNN Classification")
sns.heatmap(knn_cm, cbar=False, annot=True, cmap="rainbow", fmt="d")


plt.show()

# %%
plt.figure(figsize=(20,15))
plt.suptitle("Confusion Matrixes", fontsize=18)




plt.subplot(2,3,1)
plt.title('AdaBoost Classifier')
sns.heatmap(ab_cm, cbar=False, annot=True, cmap="rainbow", fmt="d")

plt.subplot(2,3,2)
plt.title('GradiantBoosting Classifier')
sns.heatmap(gb_cm, cbar=False, annot=True, cmap="rainbow", fmt="d")


plt.subplot(2,3,3)
plt.title('XGB Classifier')
sns.heatmap(xgb_cm, cbar=False, annot=True, cmap="rainbow", fmt="d")

plt.subplot(2,3,4)
plt.title('LGB Classifier')
sns.heatmap(lgb_cm, cbar=False, annot=True, cmap="rainbow", fmt="d")

plt.subplot(2,3,5)
plt.title('DecisionTree Classifier')
sns.heatmap(dt_cm, cbar=False, annot=True, cmap="rainbow", fmt="d")

plt.show()

# %%
TN=[mnb_cm[0,0],gnb_cm[0,0],rf_cm[0,0],lr_cm[0,0],svm_cm[0,0],knn_cm[0,0],ab_cm[0,0],gb_cm[0,0],xgb_cm[0,0],lgb_cm[0,0],dt_cm[0,0]]
FP=[mnb_cm[0,1],gnb_cm[0,1],rf_cm[0,1],lr_cm[0,1],svm_cm[0,1],knn_cm[0,1],ab_cm[0,1],gb_cm[0,1],xgb_cm[0,1],lgb_cm[0,1],dt_cm[0,1]]
FN=[mnb_cm[1,0],gnb_cm[1,0],rf_cm[1,0],lr_cm[1,0],svm_cm[1,0],knn_cm[1,0],ab_cm[1,0],gb_cm[1,0],xgb_cm[1,0],lgb_cm[1,0],dt_cm[1,0]]
TP=[mnb_cm[1,1],gnb_cm[1,1],rf_cm[1,1],lr_cm[1,1],svm_cm[1,1],knn_cm[1,1],ab_cm[1,1],gb_cm[1,1],xgb_cm[1,1],lgb_cm[1,1],dt_cm[1,1]]

# %%
accuracy['TN']=TN
accuracy['FP']=FP
accuracy['FN']=FN
accuracy['TP']=TP
accuracy
# Out:
#                           Model  Accuracy  TN  FP  FN  TP
# 0         Multinomi Naive Bayes    0.9375   0   1   0   4
# 1          Gaussian Naive Bayes    0.8125   0   1   0   4
# 2       RandomForest Classifier    0.9375   0   1   0   4
# 3           Logistic Regression    0.9375   0   1   0   4
# 4       Support Vectore Machine    0.9375   0   1   0   4
# 5          KNeigbhor Classifier    0.9375   0   1   0   4
# 6        AdaBoosting Classifier    0.8750   0   1   0   4
# 7   GradiantBoosting Classifier    0.8750   0   1   0   4
# 8                XGB Classifier    0.8125   0   1   0   3
# 9                LGB Classifier    0.9375   0   1   0   4
# 10      DecisionTree Classifier    0.9375   0   1   0   4

# %%
plt.figure(figsize=(15,8))
ax= sns.barplot(x=accuracy.Model, y=accuracy.Accuracy, palette =sns.color_palette("husl", 9) )
ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
plt.style.use('seaborn-dark-palette')
plt.xlabel('Classification Models')
plt.ylabel('Accuracy')
plt.title('Accuracy Scores of Classification Models')
for i in ax.patches:
    ax.text(i.get_x()+.19, i.get_height()-0.3, \
            str(round((i.get_height()), 4)), fontsize=15, color='b')
plt.show()

# %%
# !pip install -q streamlit

# %%
# %%writefile app.py
import streamlit as st
import tensorflow as tf
from tensorflow.keras.application
